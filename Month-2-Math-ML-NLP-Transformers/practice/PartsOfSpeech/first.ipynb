# %%
import nltk

nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('averaged_perceptron_tagger_eng')

sentence = "Rishabh is learning Natural Language Processing"

# Tokenization
words = nltk.word_tokenize(sentence)

# POS Tagging
pos_tags = nltk.pos_tag(words)

print(pos_tags)
# Out:
# [nltk_data] Downloading package punkt to /home/risha/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/risha/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /home/risha/nltk_data...
# [('Rishabh', 'NNP'), ('is', 'VBZ'), ('learning', 'VBG'), ('Natural', 'NNP'), ('Language', 'NNP'), ('Processing', 'NNP')]
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.
