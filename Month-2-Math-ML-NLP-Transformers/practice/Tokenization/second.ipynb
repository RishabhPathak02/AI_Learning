# %%
import nltk

from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer

# Downloads
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('stopwords')

# Text
text = "I am learning Natural Language Processing and loving it!"

# Tokenization
tokens = word_tokenize(text)

# Stopwords
sw = set(stopwords.words('english'))

# Stemmer
ps = PorterStemmer()

processed = []

for word in tokens:

    if word.lower() not in sw:

        stemmed = ps.stem(word)

        processed.append(stemmed) 

print(processed)
# Out:
# [nltk_data] Downloading package punkt to /home/risha/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /home/risha/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package stopwords to /home/risha/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ['learn', 'natur', 'languag', 'process', 'love', '!']
